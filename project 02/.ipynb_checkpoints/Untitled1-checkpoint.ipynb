# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# Set up the WebDriver for Microsoft Edge
driver = webdriver.Edge()

# Define the search query
query = "watch"

# Navigate to the Flipkart search page for watches
driver.get(f"https://www.flipkart.com/search?q={query}watch&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")

# Wait for page to load
time.sleep(3)

# Find all product items based on their class name
elems = driver.find_elements(By.CLASS_NAME, 'hCKiGj') 

# Print the number of items found
print(f"{len(elems)} items found")

# Loop through and print the text of each element (product)
for elem in elems:
    print(elem.text)

# Close the browser after the operation
time.sleep(2)
driver.close()
# Out:
# There was an error managing msedgedriver (error sending request for url (https://msedgedriver.azureedge.net/LATEST_RELEASE_131_WINDOWS)); using driver found in the cache
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event)
# 40 items found
# Septem
# Analog Watch - For Couple Combo Set of 2 Stylish Brown...
# ₹264₹1,59983% off
# Free delivery
# Hot Deal
# ARMADO
# Date N Day Analog Watch - For Boys AR-101-WHT New
# ₹259₹1,59983% off
# Free delivery
# Hot Deal
# PETER ENGLAND
# Analog Watch - For Men PE000017B
# ₹1,499₹3,04550% off
# Free delivery
# Hot Deal
# Haute Sauce
# Analog Watch - For Women AW24_HSWC1184
# ₹1,249₹2,69853% off
# Free delivery
# Only few left
# HALA
# Wrist Watch Sport Watch with Water Resist Feature 1260 ...
# ₹301₹1,49979% off
# Free delivery
# Only few left
# PIRASO
# Chrono Display|Analog watch|Black Dial Analog Watch - ...
# ₹349₹1,59978% off
# Free delivery
# Bank Offer
# Haute Sauce
# Analog Watch - For Women AW24_HSWC1219
# ₹989₹2,29856% off
# Free delivery
# Only few left
# Curren
# No Series Analog Watch - For Boys CR-8442
# ₹3,418₹9,99965% off
# Free delivery
# Only few left
# PROVOGUE
# Trending Premium Quality Day & Date Functioning for Boy...
# ₹359₹2,49985% off
# Free delivery
# Hot Deal
# FOSSIL
# RHETT Analog Watch - For Men BQ1009
# ₹4,909₹12,49560% off
# Free delivery
# Hot Deal
# LIMESTONE
# OTUS Limited Day and Date Functioning Series Square Dia...
# ₹349₹1,99982% off
# Free delivery
# Hot Deal
# Casado
# Branded Bracelet | Gold Plated | Studded | 3D Cut Glass...
# ₹382₹2,99987% off
# Free delivery
# Hot Deal
# VAN HEUSEN
# Analog Watch - For Women VH000008C
# ₹1,079₹2,99964% off
# Free delivery
# Hot Deal
# Gadgets World
# Fancy Design Stylish ALPHABET R Dial Black Leather Stra...
# ₹293₹99970% off
# Free delivery
# Only few left
# Allen Solly
# Analog Watch - For Men AS000010F
# ₹1,019₹2,92265% off
# Free delivery
# Hot Deal
# TIMEX
# Blue Dial Leather Strap Analog Watch - For Men TW0TG73...
# ₹609₹1,39956% off
# Free delivery
# Hot Deal
# LIMESTONE
# Brown Day and Date Functioning Check Pattern Strap Quar...
# ₹299₹1,99985% off
# Free delivery
# Hot Deal
